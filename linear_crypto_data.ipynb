# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/felipepesantez/Documents/development/datasets/crypto/coin_Bitcoin.csv")

# %%
df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
import seaborn as sns

# %%
sns.scatterplot(x="Date", y="Close", data=df)
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %%
salary_df = pd.read_csv("/Users/felipepesantez/Documents/development/datasets/Salary_dataset.csv")

# %%
salary_df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
sns.scatterplot(x="YearsExperience",y="Salary",data=salary_df)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
type(salary_df["Salary"].loc[0])
# Out:
# numpy.float64
