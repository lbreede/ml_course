# %%
import pandas as pd

# %%
import numpy as np

# %%
dataframe = pd.read_csv("/Users/felipepesantez/Documents/development/datasets/singapore_airlines_reviews.csv")

# %%
dataframe
# Out:
#                  published_date published_platform  rating    type  \
# 0     2024-03-12T14:41:14-04:00            Desktop       3  review
# 1     2024-03-11T19:39:13-04:00            Desktop       5  review
# 2     2024-03-11T12:20:23-04:00            Desktop       1  review
# 3     2024-03-11T07:12:27-04:00            Desktop       5  review
# 4     2024-03-10T05:34:18-04:00            Desktop       2  review
# ...                         ...                ...     ...     ...
# 9995  2018-08-06T03:48:21-04:00            Desktop       5  review
# 9996  2018-08-05T22:50:29-04:00             Mobile       5  review
# 9997  2018-08-05T22:47:06-04:00            Desktop       5  review
# 9998  2018-08-05T20:32:03-04:00            Desktop       4  review
# 9999  2018-08-05T20:19:51-04:00            Desktop       4  review
#
#                                                    text  \
# 0     We used this airline to go from Singapore to L...
# ...

# %%
dataframe.head()
# Out:
#               published_date published_platform  rating    type  \
# 0  2024-03-12T14:41:14-04:00            Desktop       3  review
# 1  2024-03-11T19:39:13-04:00            Desktop       5  review
# 2  2024-03-11T12:20:23-04:00            Desktop       1  review
# 3  2024-03-11T07:12:27-04:00            Desktop       5  review
# 4  2024-03-10T05:34:18-04:00            Desktop       2  review
#
#                                                 text  \
# 0  We used this airline to go from Singapore to L...
# 1  The service on Singapore Airlines Suites Class...
# 2  Booked, paid and received email confirmation f...
# 3  Best airline in the world, seats, food, servic...
# 4  Premium Economy Seating on Singapore Airlines ...
#
#                                                title  helpful_votes
# 0                                                 Ok              0
# 1  The service in Suites Class makes one feel lik...              0
# ...

# %%
dataframe.head(7)
# Out:
#               published_date published_platform  rating    type  \
# 0  2024-03-12T14:41:14-04:00            Desktop       3  review
# 1  2024-03-11T19:39:13-04:00            Desktop       5  review
# 2  2024-03-11T12:20:23-04:00            Desktop       1  review
# 3  2024-03-11T07:12:27-04:00            Desktop       5  review
# 4  2024-03-10T05:34:18-04:00            Desktop       2  review
# 5  2024-03-10T01:16:48-05:00            Desktop       1  review
# 6  2024-03-10T00:54:43-05:00            Desktop       5  review
#
#                                                 text  \
# 0  We used this airline to go from Singapore to L...
# 1  The service on Singapore Airlines Suites Class...
# 2  Booked, paid and received email confirmation f...
# 3  Best airline in the world, seats, food, servic...
# 4  Premium Economy Seating on Singapore Airlines ...
# 5  We booked our flights a full 9 months in advan...
# 6  This was a fascinating experience. As I sat in...
#
# ...

# %%
dataframe.tail()
# Out:
#                  published_date published_platform  rating    type  \
# 9995  2018-08-06T03:48:21-04:00            Desktop       5  review
# 9996  2018-08-05T22:50:29-04:00             Mobile       5  review
# 9997  2018-08-05T22:47:06-04:00            Desktop       5  review
# 9998  2018-08-05T20:32:03-04:00            Desktop       4  review
# 9999  2018-08-05T20:19:51-04:00            Desktop       4  review
#
#                                                    text  \
# 9995  First part done with Singapore Airlines - acce...
# 9996  And again a great Flight with Singapore Air. G...
# 9997  We flew business class from Frankfurt, via Sin...
# 9998  As always, the A380 aircraft was spotlessly pr...
# 9999  As always, Singapore Airlines has done it agai...
#
#                                                   title  helpful_votes
# 9995  Flew to NZ 1st half Singapore Airlines, 2nd ha...              1
# 9996                                       Best Airline              1
# ...

# %%
dataframe.info
# Out:
# <bound method DataFrame.info of                  published_date published_platform  rating    type  \
# 0     2024-03-12T14:41:14-04:00            Desktop       3  review
# 1     2024-03-11T19:39:13-04:00            Desktop       5  review
# 2     2024-03-11T12:20:23-04:00            Desktop       1  review
# 3     2024-03-11T07:12:27-04:00            Desktop       5  review
# 4     2024-03-10T05:34:18-04:00            Desktop       2  review
# ...                         ...                ...     ...     ...
# 9995  2018-08-06T03:48:21-04:00            Desktop       5  review
# 9996  2018-08-05T22:50:29-04:00             Mobile       5  review
# 9997  2018-08-05T22:47:06-04:00            Desktop       5  review
# 9998  2018-08-05T20:32:03-04:00            Desktop       4  review
# 9999  2018-08-05T20:19:51-04:00            Desktop       4  review
#
#                                                    text  \
# 0     We used this airline to go from Singapore to L...
# ...

# %%
dataframe.describe()
# Out:
#              rating  helpful_votes
# count  10000.000000   10000.000000
# mean       4.015800       1.275200
# std        1.346006       2.721618
# min        1.000000       0.000000
# 25%        3.000000       0.000000
# 50%        5.000000       1.000000
# 75%        5.000000       2.000000
# max        5.000000     158.000000

# %%
dataframe.head()
# Out:
#               published_date published_platform  rating    type  \
# 0  2024-03-12T14:41:14-04:00            Desktop       3  review
# 1  2024-03-11T19:39:13-04:00            Desktop       5  review
# 2  2024-03-11T12:20:23-04:00            Desktop       1  review
# 3  2024-03-11T07:12:27-04:00            Desktop       5  review
# 4  2024-03-10T05:34:18-04:00            Desktop       2  review
#
#                                                 text  \
# 0  We used this airline to go from Singapore to L...
# 1  The service on Singapore Airlines Suites Class...
# 2  Booked, paid and received email confirmation f...
# 3  Best airline in the world, seats, food, servic...
# 4  Premium Economy Seating on Singapore Airlines ...
#
#                                                title  helpful_votes
# 0                                                 Ok              0
# 1  The service in Suites Class makes one feel lik...              0
# ...

# %%
dataframe.columns
# Out:
# Index(['published_date', 'published_platform', 'rating', 'type', 'text',
#        'title', 'helpful_votes'],
#       dtype='object')

# %%
dataframe.rating
# Out:
# 0       3
# 1       5
# 2       1
# 3       5
# 4       2
#        ..
# 9995    5
# 9996    5
# 9997    5
# 9998    4
# 9999    4
# Name: rating, Length: 10000, dtype: int64

# %%
dataframe["rating"]
# Out:
# 0       3
# 1       5
# 2       1
# 3       5
# 4       2
#        ..
# 9995    5
# 9996    5
# 9997    5
# 9998    4
# 9999    4
# Name: rating, Length: 10000, dtype: int64

# %%
dataframe.head()
# Out:
#               published_date published_platform  rating    type  \
# 0  2024-03-12T14:41:14-04:00            Desktop       3  review
# 1  2024-03-11T19:39:13-04:00            Desktop       5  review
# 2  2024-03-11T12:20:23-04:00            Desktop       1  review
# 3  2024-03-11T07:12:27-04:00            Desktop       5  review
# 4  2024-03-10T05:34:18-04:00            Desktop       2  review
#
#                                                 text  \
# 0  We used this airline to go from Singapore to L...
# 1  The service on Singapore Airlines Suites Class...
# 2  Booked, paid and received email confirmation f...
# 3  Best airline in the world, seats, food, servic...
# 4  Premium Economy Seating on Singapore Airlines ...
#
#                                                title  helpful_votes
# 0                                                 Ok              0
# 1  The service in Suites Class makes one feel lik...              0
# ...

# %%
dataframe.loc[4]
# Out:
# published_date                                2024-03-10T05:34:18-04:00
# published_platform                                              Desktop
# rating                                                                2
# type                                                             review
# text                  Premium Economy Seating on Singapore Airlines ...
# title                 Premium Economy Seating on Singapore Airlines ...
# helpful_votes                                                         0
# Name: 4, dtype: object

# %%
dataframe.iloc[0]
# Out:
# published_date                                2024-03-12T14:41:14-04:00
# published_platform                                              Desktop
# rating                                                                3
# type                                                             review
# text                  We used this airline to go from Singapore to L...
# title                                                                Ok
# helpful_votes                                                         0
# Name: 0, dtype: object

# %%
dataframe.iloc[20:51]
# Out:
#                published_date published_platform  rating    type  \
# 20  2024-03-01T12:39:26-05:00            Desktop       1  review
# 21  2024-03-01T11:30:33-05:00            Desktop       1  review
# 22  2024-02-29T01:02:20-05:00            Desktop       5  review
# 23  2024-02-26T09:49:13-05:00            Desktop       3  review
# 24  2024-02-22T03:52:54-05:00            Desktop       5  review
# 25  2024-02-22T01:11:55-05:00            Desktop       3  review
# 26  2024-02-21T09:56:24-05:00            Desktop       1  review
# 27  2024-02-19T19:25:02-05:00            Desktop       1  review
# 28  2024-02-18T23:44:52-05:00            Desktop       4  review
# 29  2024-02-18T00:29:30-05:00            Desktop       2  review
# 30  2024-02-17T07:22:55-05:00            Desktop       3  review
# 31  2024-02-16T00:39:41-05:00            Desktop       5  review
# 32  2024-02-15T18:39:29-05:00            Desktop       1  review
# ...
