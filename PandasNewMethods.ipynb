# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/felipepesantez/Documents/development/datasets/las_vegas_airbnb_data.csv")

# %%
df.head()
# Out:
#                roomType  stars                           address  \
# 0          Entire condo   4.54  Las Vegas, Nevada, United States
# 1    Entire rental unit   4.39  Las Vegas, Nevada, United States
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  price  \
# 0               4                  Doug    NaN
# 1               4                  Doug    NaN
# 2               4            Aaron&Tina    NaN
# 3               6            Aaron&Tina    NaN
# 4               2                  Brad    NaN
#
#                                  firstReviewComments  firstReviewRating
# 0  Overall, I had a good experience. The only dow...                4.0
# 1  I stayed an extra night. That should sum it up...                5.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   roomType               1000 non-null   object
#  1   stars                  723 non-null    float64
#  2   address                1000 non-null   object
#  3   numberOfGuests         1000 non-null   int64
#  4   primaryHost/smartName  1000 non-null   object
#  5   price                  0 non-null      float64
#  6   firstReviewComments    795 non-null    object
#  7   firstReviewRating      795 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#             stars  numberOfGuests  price  firstReviewRating
# count  723.000000     1000.000000    0.0         795.000000
# mean     4.836528        7.070000    NaN           4.794969
# std      0.167377        3.959644    NaN           0.661633
# min      3.670000        1.000000    NaN           1.000000
# 25%      4.770000        4.000000    NaN           5.000000
# 50%      4.870000        6.000000    NaN           5.000000
# 75%      4.960000        8.000000    NaN           5.000000
# max      5.000000       16.000000    NaN           5.000000

# %%
df.head()
# Out:
#                roomType  stars                           address  \
# 0          Entire condo   4.54  Las Vegas, Nevada, United States
# 1    Entire rental unit   4.39  Las Vegas, Nevada, United States
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  price  \
# 0               4                  Doug    NaN
# 1               4                  Doug    NaN
# 2               4            Aaron&Tina    NaN
# 3               6            Aaron&Tina    NaN
# 4               2                  Brad    NaN
#
#                                  firstReviewComments  firstReviewRating
# 0  Overall, I had a good experience. The only dow...                4.0
# 1  I stayed an extra night. That should sum it up...                5.0
# ...

# %%
df[["stars","numberOfGuests"]]
# Out:
#      stars  numberOfGuests
# 0     4.54               4
# 1     4.39               4
# 2      NaN               4
# 3      NaN               6
# 4     4.51               2
# ..     ...             ...
# 995   5.00               4
# 996   4.77               7
# 997   4.93               2
# 998   5.00               8
# 999    NaN               8
#
# [1000 rows x 2 columns]

# %%
type(df["stars"])
# Out:
# pandas.core.series.Series

# %%
df["new_col"] = df["numberOfGuests"] + df["firstReviewRating"]

# %%
df
# Out:
#                  roomType  stars  \
# 0            Entire condo   4.54
# 1      Entire rental unit   4.39
# 2      Entire guest suite    NaN
# 3            Entire condo    NaN
# 4    Private room in home   4.51
# ..                    ...    ...
# 995          Entire condo   5.00
# 996           Entire home   4.77
# 997          Entire condo   4.93
# 998           Entire home   5.00
# 999         Room in hotel    NaN
#
#                                               address  numberOfGuests  \
# 0                    Las Vegas, Nevada, United States               4
# 1                    Las Vegas, Nevada, United States               4
# 2                    Las Vegas, Nevada, United States               4
# 3                    Las Vegas, Nevada, United States               6
# 4                    Las Vegas, Nevada, United States               2
# ..                                                ...             ...
# ...

# %%
df.head()
# Out:
#                roomType  stars                           address  \
# 0          Entire condo   4.54  Las Vegas, Nevada, United States
# 1    Entire rental unit   4.39  Las Vegas, Nevada, United States
# 2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 3          Entire condo    NaN  Las Vegas, Nevada, United States
# 4  Private room in home   4.51  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  price  \
# 0               4                  Doug    NaN
# 1               4                  Doug    NaN
# 2               4            Aaron&Tina    NaN
# 3               6            Aaron&Tina    NaN
# 4               2                  Brad    NaN
#
#                                  firstReviewComments  firstReviewRating  \
# 0  Overall, I had a good experience. The only dow...                4.0
# 1  I stayed an extra night. That should sum it up...                5.0
# ...

# %%
df.drop("price", axis=1, inplace=True)

# %%
df
# Out:
#                  roomType  stars  \
# 0            Entire condo   4.54
# 1      Entire rental unit   4.39
# 2      Entire guest suite    NaN
# 3            Entire condo    NaN
# 4    Private room in home   4.51
# ..                    ...    ...
# 995          Entire condo   5.00
# 996           Entire home   4.77
# 997          Entire condo   4.93
# 998           Entire home   5.00
# 999         Room in hotel    NaN
#
#                                               address  numberOfGuests  \
# 0                    Las Vegas, Nevada, United States               4
# 1                    Las Vegas, Nevada, United States               4
# 2                    Las Vegas, Nevada, United States               4
# 3                    Las Vegas, Nevada, United States               6
# 4                    Las Vegas, Nevada, United States               2
# ..                                                ...             ...
# ...

# %%
df.drop(0, axis=0, inplace=True)

# %%
df.head()
# Out:
#    index              roomType  stars                           address  \
# 1      2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 2      3          Entire condo    NaN  Las Vegas, Nevada, United States
# 3      4  Private room in home   4.51  Las Vegas, Nevada, United States
# 4      5           Entire home   4.96  Las Vegas, Nevada, United States
# 5      6         Room in hotel    NaN  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  \
# 1               4            Aaron&Tina
# 2               6            Aaron&Tina
# 3               2                  Brad
# 4              15                 Simon
# 5               4             Suiteness
#
#                                  firstReviewComments  firstReviewRating  \
# 1  These days things are so impersonable but she ...                5.0
# 2  Great response time from owner. Could message ...                5.0
# ...

# %%
df.loc[[1,2,3,4],["roomType","stars","address","numberOfGuests"]]
# Out:
#                roomType  stars                           address  \
# 1    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 2          Entire condo    NaN  Las Vegas, Nevada, United States
# 3  Private room in home   4.51  Las Vegas, Nevada, United States
# 4           Entire home   4.96  Las Vegas, Nevada, United States
#
#    numberOfGuests
# 1               4
# 2               6
# 3               2
# 4              15

# %%
df[df["numberOfGuests"]<4].head()
# Out:
#      index              roomType  stars                           address  \
# 3        4  Private room in home   4.51  Las Vegas, Nevada, United States
# 177    178  Private room in home   5.00  Las Vegas, Nevada, United States
# 220    221             Camper/RV   4.89  Las Vegas, Nevada, United States
# 222    223    Entire guest suite   4.60  Las Vegas, Nevada, United States
# 239    240         Room in hotel    NaN  Las Vegas, Nevada, United States
#
#      numberOfGuests primaryHost/smartName  \
# 3                 2                  Brad
# 177               2                Carlos
# 220               2                  Brad
# 222               2                Hernan
# 239               3             Suiteness
#
#                                    firstReviewComments  firstReviewRating  \
# 3    good group of guys in the house. quiet clean a...                5.0
# 177  Was in a quiet neighborhood, host was extremel...                5.0
# ...

# %%
df[df["primaryHost/smartName"]=="Brad"]
# Out:
#      index              roomType  stars                           address  \
# 3        4  Private room in home   4.51  Las Vegas, Nevada, United States
# 220    221             Camper/RV   4.89  Las Vegas, Nevada, United States
#
#      numberOfGuests primaryHost/smartName  \
# 3                 2                  Brad
# 220               2                  Brad
#
#                                    firstReviewComments  firstReviewRating  \
# 3    good group of guys in the house. quiet clean a...                5.0
# 220                                    Friendly people                5.0
#
#      new_col
# 3        7.0
# 220      7.0

# %%
df[(df["numberOfGuests"]==2) & (df["firstReviewRating"]<5.0)]
# Out:
#      index              roomType  stars  \
# 576    577  Private room in home   4.93
# 608    609          Entire condo   4.55
# 636    637    Entire guest suite   4.81
# 642    643           Entire home   4.81
# 645    646           Entire home   4.87
# 646    647           Entire home   4.61
# 657    658          Entire villa   4.86
# 718    719    Entire guest suite   4.91
# 792    793          Entire condo   4.00
# 806    807     Entire guesthouse   4.77
# 821    822  Private room in home   4.97
# 825    826    Entire rental unit   4.87
# 930    931     Entire guesthouse   4.76
# 944    945    Entire guest suite   4.82
#
#                                     address  numberOfGuests  \
# 576        Las Vegas, Nevada, United States               2
# 608        Las Vegas, Nevada, United States               2
# 636        Las Vegas, Nevada, United States               2
# 642        Las Vegas, Nevada, United States               2
# ...

# %%
df.head()
# Out:
#    index              roomType  stars                           address  \
# 1      2    Entire guest suite    NaN  Las Vegas, Nevada, United States
# 2      3          Entire condo    NaN  Las Vegas, Nevada, United States
# 3      4  Private room in home   4.51  Las Vegas, Nevada, United States
# 4      5           Entire home   4.96  Las Vegas, Nevada, United States
# 5      6         Room in hotel    NaN  Las Vegas, Nevada, United States
#
#    numberOfGuests primaryHost/smartName  \
# 1               4            Aaron&Tina
# 2               6            Aaron&Tina
# 3               2                  Brad
# 4              15                 Simon
# 5               4             Suiteness
#
#                                  firstReviewComments  firstReviewRating  \
# 1  These days things are so impersonable but she ...                5.0
# 2  Great response time from owner. Could message ...                5.0
# ...

# %%
df.reset_index()
# Out:
#      level_0  index              roomType  stars  \
# 0          1      2    Entire guest suite    NaN
# 1          2      3          Entire condo    NaN
# 2          3      4  Private room in home   4.51
# 3          4      5           Entire home   4.96
# 4          5      6         Room in hotel    NaN
# ..       ...    ...                   ...    ...
# 993      994    995          Entire condo   5.00
# 994      995    996           Entire home   4.77
# 995      996    997          Entire condo   4.93
# 996      997    998           Entire home   5.00
# 997      998    999         Room in hotel    NaN
#
#                                               address  numberOfGuests  \
# 0                    Las Vegas, Nevada, United States               4
# 1                    Las Vegas, Nevada, United States               6
# 2                    Las Vegas, Nevada, United States               2
# 3                    Las Vegas, Nevada, United States              15
# ...
